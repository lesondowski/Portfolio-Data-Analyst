# %% [markdown]
# import thư viện

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# tổng quan về dataset

# %%
df = pd.read_csv("tips.csv")
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# thông tin về dataset raw

# %%
df = pd.read_csv("./tips_deduplicated_minmax.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  243 non-null    float64
#  1   tip         243 non-null    float64
#  2   sex         243 non-null    object
#  3   smoker      243 non-null    object
#  4   day         243 non-null    object
#  5   time        243 non-null    object
#  6   size        243 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# Như vậy với 244 dòng dữ liệu, ta không thấy có giá trị trống trong tập dữ liệu. vì vậy bước tiến hành xử lý giá trị trống trong phần tiền xử lý dữ liệu sẽ bị bỏ qua.

# %% [markdown]
# tiền xử lý dữ liệu

# %% [markdown]
# xử lý dữ liệu bị trùng

# %%
df = pd.read_csv("./tips.csv")
dupli = df.duplicated()
print(df[dupli])
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %% [markdown]
# kiểm tra dữ liệu bị trùng

# %%
def remove_duplicates(file):
  df = pd.read_csv(file)
  df.drop_duplicates(inplace=True)
  df.to_csv(file.replace(".csv", "_deduplicated.csv"), index=False)
remove_duplicates("tips.csv")
df = pd.read_csv("./tips_deduplicated.csv")
dupli = df.duplicated()
print(df[dupli])
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
def check_empty_data(file_path):
  df = pd.read_csv(file_path)
  empty_rows = df[df.isnull().any(axis=1)]
  if not empty_rows.empty:
    print(f"có {len(empty_rows)} dòng có dữ liệu trống:")
    print(empty_rows)
  else:
    print(f"không có dữ liệu trống.")

check_empty_data('./tips_deduplicated.csv')
# Out:
# không có dữ liệu trống.

# %% [markdown]
# Với tập dữ liệu hiện có, dataset khônng có quá nhiều cột (7 cột) và ta nhận thấy không có cột nào dư thừa hoặc không gây ảnh hưởng tới kết quả dự đoán. vì vậy ta tiến hành bỏ qua việc loại bỏ cột dư thừa.

# %% [markdown]
# -> xử lý giá trị trong tập dữ liệu:

# %%
df = pd.read_csv("./tips_deduplicated.csv")
print(df.describe())
df.describe(include="all").T.round(2)
# Out:
#        total_bill         tip        size
# count  243.000000  243.000000  243.000000
# mean    19.813868    3.002387    2.572016
# std      8.910071    1.385002    0.952356
# min      3.070000    1.000000    1.000000
# 25%     13.380000    2.000000    2.000000
# 50%     17.810000    2.920000    2.000000
# 75%     24.175000    3.575000    3.000000
# max     50.810000   10.000000    6.000000
#             count unique     top freq       mean       std   min    25%  \
# total_bill  243.0    NaN     NaN  NaN  19.813868  8.910071  3.07  13.38
# tip         243.0    NaN     NaN  NaN   3.002387  1.385002   1.0    2.0
# sex           243      2    Male  157        NaN       NaN   NaN    NaN
# smoker        243      2      No  151        NaN       NaN   NaN    NaN
# day           243      4     Sat   87        NaN       NaN   NaN    NaN
# time          243      2  Dinner  176        NaN       NaN   NaN    NaN
# size        243.0    NaN     NaN  NaN   2.572016  0.952356   1.0    2.0
#
#               50%     75%    max
# total_bill  17.81  24.175  50.81
# tip          2.92   3.575   10.0
# sex           NaN     NaN    NaN
# smoker        NaN     NaN    NaN
# day           NaN     NaN    NaN
# time          NaN     NaN    NaN
# size          2.0     3.0    6.0

# %% [markdown]
# với các giá trị min, max, trung vị, trung bình trong tập dữ liệu tương đối ổn nên ta sẽ không tiến hành xử lý các giá trị quá chênh lệnh so với tập dữ liệu.

# %% [markdown]
# CHUẢN HÓA DỮ LIỆU

# %% [markdown]
# phân tích đơn biến

# %%
df = pd.read_csv("tips_deduplicated.csv")
for column in df.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=df, x=column, color='#FF69B4')
    plt.title(f"Biểu đồ cột {column}")
    plt.show()
    print("-" * 90)
# Out:
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

# %% [markdown]
# chuẩn hóa dữ liệu

# %%
def min_max_scaling(file):
  df = pd.read_csv(file)
  for column in df.columns:
    if df[column].dtype != 'object':
      min_val = df[column].min()
      max_val = df[column].max()
      df[column] = (df[column] - min_val) / (max_val - min_val)
  # Lưu file CSV đã chuẩn hóa vào file mới
  df.to_csv(file.replace(".csv", "_minmax.csv"), index=False)
min_max_scaling("tips_deduplicated.csv" )

# %% [markdown]
# headmap

# %%
df = pd.read_csv("./tips_deduplicated_minmax.csv")

# Chuyển đổi các cột không phải số thành số
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = pd.Categorical(df[column]).codes

# Vẽ biểu đồ heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Biểu đồ Heatmap cho dữ liệu 'tips_deduplicated.csv'")
plt.show()

# %%
def analyze_multivariate(file):
  df = pd.read_csv(file)
  for column in df.columns:
    if df[column].dtype == 'object':
      le = LabelEncoder()
      df[column] = le.fit_transform(df[column])

  sns.pairplot(df, hue='sex', diag_kind='kde')
  plt.title("Biểu đồ Pairplot ")
  plt.show()

  # Vẽ biểu đồ Heatmap
  plt.figure(figsize=(10, 8))
  sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
  plt.title("Biểu đồ Heatmap ")
  plt.show()
analyze_multivariate("tips_deduplicated.csv" )

# %%
df = pd.read_csv("./tips_deduplicated.csv")
plt.scatter(df["total_bill"], df["tip"])
plt.show()

# %%
data = pd.read_csv("./tips_deduplicated.csv")

data = data.drop(["sex", "smoker", "day", "time", "size"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(data.drop("tip", axis=1), data["tip"], test_size=0.2, random_state=42)

# Create and train Random Forest Regressor
model = rf1 = RandomForestRegressor()
model.fit(X_train, y_train)
# Predict tip amount on the test set
y_pred = model.predict(X_test)
# Calculate mean absolute error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.905544557823129

# %%
data = pd.read_csv("./tips_deduplicated.csv")
data = pd.get_dummies(data, columns=["smoker", "sex", "time"])
features = data.drop("tip", axis=1)
features = features.drop("day", axis=1)

target = data["tip"]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=20) # tuy chinh randomstate
model = LinearRegression()
model.fit(X_train, y_train)

# Đánh giá mô hình
y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
mse = mean_squared_error(y_test, y_pred)  # Tính MSE
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred) 

fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].scatter(X_test.iloc[:, 0], y_pred)  
axes[1].scatter(X_test.iloc[:, 0], y_test)
axes[0].set_title("Predicted")
axes[1].set_title("Actual")
plt.suptitle("{}\nMSE: {}\nR2: {}".format("", round(mse, 4), round(r2, 4)))
plt.tight_layout()
plt.show()

print("MSE:", mse)
print("MAE:", mae)  # In ra MSE
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# MSE: 1.0263134703831307
# MAE: 0.7942588907473634

# %% [markdown]
# MÔ HÌNH LINEAR REGRESSION

# %%
data = pd.read_csv("./tips_deduplicated.csv")
data = pd.get_dummies(data, columns=[ "smoker", "sex", "time"])
features = data.drop("tip", axis=1)
features = features.drop("day", axis=1)
target = data["tip"]


# Chia dữ liệu thành tập train và tập test
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42) # tuy chinh gia tri

# Tạo mô hình Linear Regression
model = RandomForestRegressor(n_estimators=130, random_state=20)

# Huấn luyện mô hình
model.fit(X_train, y_train)

# Đánh giá mô hình
y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
mse = mean_squared_error(y_test, y_pred)  # Tính MSE
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)  # Sửa lại thứ tự tham số

fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].scatter(X_test.iloc[:, 0], y_pred)  # Sử dụng iloc để truy cập cột đầu tiên
axes[1].scatter(X_test.iloc[:, 0], y_test)
axes[0].set_title("Predicted")
axes[1].set_title("Actual")
plt.suptitle("{}\nMSE: {}\nR2: {}".format("", round(mse, 4), round(r2, 4)))
plt.tight_layout()
plt.show()

print("MSE:", mse)
print("MAE:", mae)  # In ra MSE
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# MSE: 1.3951215060982967
# MAE: 0.8634662480376766

# %% [markdown]
# MÔ HÌNH RANDOM FOREST

# %% [markdown]
# Lưu ý:
# để thực hiện việc loại bỏ cột để xem sự thay đổi kết quả của mô hình, nếu cột dữ liệu là định dạng object trong dataset thì phải lược bỏ cột đó trong mục biến đổi thành dạng số (data)
# sau đó điền tên cột cần bỏ vào biến X

# %%
data = pd.read_csv('./tips_deduplicated.csv')  

data = pd.get_dummies(data, columns=[ 'sex', 'smoker', 'time'])
x = data.drop('tip', axis=1)
x = x.drop("day", axis=1)
y = data['tip'] # labels
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Khởi tạo mô hình
model = RandomForestRegressor(n_estimators=130, random_state=20)
model.fit(X_train, y_train)

# Dự đoán
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

#  tầm quan trọng của các biến
feature_importances = pd.DataFrame({'feature': x.columns, 'importance': model.feature_importances_})
print(feature_importances.sort_values(by='importance', ascending=False))
# Out:
# Mean Squared Error: 1.3869071853640862
# R-squared: 0.43077308171469086
#        feature  importance
# 0   total_bill    0.800249
# 1         size    0.059957
# 5   smoker_Yes    0.037374
# 4    smoker_No    0.031079
# 7   time_Lunch    0.019921
# 3     sex_Male    0.017406
# 6  time_Dinner    0.017201
# 2   sex_Female    0.016813
